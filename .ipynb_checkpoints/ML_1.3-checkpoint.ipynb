# %%
from catboost import CatBoostClassifier
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import ConfusionMatrixDisplay, recall_score, roc_auc_score
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from IPython.display import display

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import joblib

# %% [markdown]
# #### Nesse notebook, geraremos um modelo simplificado, sem GridSearch, sem StratifiedKFold, apenas pra gerar nossa primeira pravisão e submissão, e avaliar o progresso do nosso modelo ao longo do percurso.

# %%
class FeatureEngineer(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        X=X.copy()
        X['Total_vs_monthly'] = X['TotalCharges']/X['MonthlyCharges']
        
        return X

# %%
df.head(5)
# Out:
#    id  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   0    Male             0     Yes        Yes      29          Yes
# 1   1    Male             0     Yes        Yes      58          Yes
# 2   2    Male             0     Yes         No      58          Yes
# 3   3  Female             0      No         No       1          Yes
# 4   4  Female             0      No         No       1          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No             DSL            Yes  ...              Yes
# 1            No             DSL            Yes  ...               No
# 2           Yes     Fiber optic             No  ...               No
# 3            No     Fiber optic             No  ...               No
# 4            No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0         Yes          No              No        One year              Yes
# 1         Yes         Yes              No        Two year               No
# 2          No         Yes             Yes  Month-to-month              Yes
# 3          No          No              No  Month-to-month              Yes
# 4          No          No              No  Month-to-month              Yes
#
#              PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0             Mailed check          60.10       1653.85      0
# 1  Credit card (automatic)          69.50       3778.20      0
# 2         Electronic check         100.40       5841.35      0
# 3         Electronic check          69.70         70.70      1
# 4         Electronic check          70.45         70.45      1
#
# [5 rows x 21 columns]

# %%
df = joblib.load('df_att.pkl')

index = df['id']

target = 'Churn'

X = df.drop([target, 'id'], axis=1)
y = df[target]

# %%
X.head()
# Out:
#    gender SeniorCitizen Partner Dependents  tenure PhoneService MultipleLines  \
# 0    Male             0     Yes        Yes      29          Yes            No
# 1    Male             0     Yes        Yes      58          Yes            No
# 2    Male             0     Yes         No      58          Yes           Yes
# 3  Female             0      No         No       1          Yes            No
# 4  Female             0      No         No       1          Yes            No
#
#   InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0             DSL            Yes           No              Yes         Yes
# 1             DSL            Yes          Yes               No         Yes
# 2     Fiber optic             No          Yes               No          No
# 3     Fiber optic             No           No               No          No
# 4     Fiber optic             No           No               No          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No              No        One year              Yes
# 1         Yes              No        Two year               No
# 2         Yes             Yes  Month-to-month              Yes
# 3          No              No  Month-to-month              Yes
# 4          No              No  Month-to-month              Yes
#
#              PaymentMethod  MonthlyCharges  TotalCharges
# 0             Mailed check           60.10       1653.85
# 1  Credit card (automatic)           69.50       3778.20
# 2         Electronic check          100.40       5841.35
# 3         Electronic check           69.70         70.70
# 4         Electronic check           70.45         70.45

# %%
def extract_xy(df):
    target = 'Churn'
    X = df.drop([target, 'id'], axis=1)
    y = df[target]
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

    return X_train, X_val, y_train, y_val

# %%
X_train, X_val, y_train, y_val = extract_xy(df)

cat_features = X_train.select_dtypes(exclude='number').columns.tolist()
num_features = X_train.select_dtypes(include='number').columns.tolist()

# %%
X_train
# Out:
#         gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 220325    Male             1      No         No      23          Yes
# 305075  Female             0     Yes        Yes      70          Yes
# 460412  Female             0      No         No      18          Yes
# 361575  Female             0      No        Yes       9          Yes
# 121133  Female             0      No         No       3           No
# ...        ...           ...     ...        ...     ...          ...
# 404661  Female             0     Yes        Yes      17          Yes
# 296515  Female             1      No         No       7          Yes
# 97289     Male             0      No         No      36          Yes
# 257525  Female             0     Yes        Yes      51          Yes
# 27709   Female             0      No         No      17          Yes
#
#            MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 220325               Yes     Fiber optic            Yes           No
# 305075               Yes     Fiber optic            Yes           No
# 460412               Yes     Fiber optic             No           No
# 361575                No     Fiber optic             No           No
# 121133  No phone service             DSL             No           No
# ...                  ...             ...            ...          ...
# 404661                No             DSL             No           No
# 296515               Yes     Fiber optic             No           No
# 97289                Yes     Fiber optic            Yes          Yes
# 257525                No             DSL             No           No
# 27709                Yes     Fiber optic             No           No
#
#        DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 220325               No          No         Yes              No
# 305075               No          No         Yes             Yes
# 460412               No          No          No              No
# 361575               No          No          No              No
# 121133              Yes          No          No              No
# ...                 ...         ...         ...             ...
# 404661               No         Yes          No              No
# 296515               No          No          No              No
# 97289                No          No         Yes             Yes
# 257525               No         Yes          No              No
# 27709                No          No          No              No
#
#               Contract PaperlessBilling              PaymentMethod  \
# 220325  Month-to-month              Yes           Electronic check
# 305075        Two year              Yes    Credit card (automatic)
# 460412  Month-to-month              Yes           Electronic check
# 361575  Month-to-month               No               Mailed check
# 121133  Month-to-month               No           Electronic check
# ...                ...              ...                        ...
# 404661        One year               No               Mailed check
# 296515  Month-to-month              Yes           Electronic check
# 97289   Month-to-month              Yes           Electronic check
# 257525  Month-to-month               No  Bank transfer (automatic)
# 27709   Month-to-month              Yes           Electronic check
#
#         MonthlyCharges  TotalCharges
# 220325           88.85       2193.65
# 305075           99.30       6725.50
# 460412           74.75       1340.80
# 361575           69.15        572.45
# 121133           29.65         82.35
# ...                ...           ...
# 404661           50.70        765.15
# 296515           74.85        477.80
# 97289           105.45       3409.60
# 257525           50.30       2633.40
# 27709            80.50       1470.10
#
# [475355 rows x 19 columns]

# %%
model = CatBoostClassifier(iterations = 108, learning_rate=0.6, depth=6, l2_leaf_reg=1.2, border_count=150, eval_metric='AUC', cat_features=cat_features, verbose=100)

# %%
pipe = Pipeline([
    ('fe', FeatureEngineer()),
    ('model', model)
])

# %%
pipe.fit(X_train, y_train)
# Out:
# 0:	total: 344ms	remaining: 36.8s
# 100:	total: 18.7s	remaining: 1.3s
# 107:	total: 20s	remaining: 0us
# Pipeline(steps=[('fe', FeatureEngineer()),
#                 ('model',
#                  CatBoostClassifier(border_count=150, cat_features=['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod'], depth=6, eval_metric='AUC', iterations=108, l2_leaf_reg=1.2, learning_rate=0.6, verbose=100))])

# %%
pred = pipe.predict(X_val)

score = roc_auc_score(y_val, pred)
score
# Out:
# 0.780929725025864

# %%
pipe.named_steps['model'].feature_importances_
# Out:
# array([ 0.05988192,  1.62749656,  0.31402311,  1.36507089, 17.09280777,
#         0.62298351,  0.91396388,  0.34056497,  1.9224682 ,  0.55131063,
#         0.40142142,  0.90796211,  0.18352795,  0.66292056, 14.12112707,
#         7.36044792,  5.27551075, 27.45671681,  4.13981583, 14.67997814])

# %%
pipe.fit(X, y)
# Out:
# 0:	total: 215ms	remaining: 23s
# 100:	total: 21s	remaining: 1.46s
# 107:	total: 22.5s	remaining: 0us
# Pipeline(steps=[('fe', FeatureEngineer()),
#                 ('model',
#                  CatBoostClassifier(border_count=150, cat_features=['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod'], depth=6, eval_metric='AUC', iterations=108, l2_leaf_reg=1.2, learning_rate=0.6, verbose=100))])

# %%
test = joblib.load('test_att.pkl')
index = test['id']
test = test.drop('id', axis=1)

# %%
test_fe = pipe.named_steps['fe'].transform(test)

# %%
test_predict = model.predict_proba(test_fe)[:,1]
test_predict
# Out:
# array([0.07761353, 0.00159991, 0.11655012, ..., 0.29833493, 0.00173841,
#        0.39765962], shape=(254655,))

# %%
df_test = pd.DataFrame({'id': index, 'Churn': test_predict})

df_test.head(3)
# Out:
#        id     Churn
# 0  594194  0.077614
# 1  594195  0.001600
# 2  594196  0.116550

# %%
df_test.to_csv('1.2_submission.csv', index=False)

# %%
predict = pipe.predict(X_val)

# %%
ConfusionMatrixDisplay.from_predictions(y_val, predict, normalize='true')

# %%
recall = recall_score(y_val, predict)

# %%
recall
# Out:
# 0.6440436461809592

# %%
df = pipe.named_steps['fe'].fit_transform(df)

# %%
df.head()
# Out:
#    id  gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   0    Male             0     Yes        Yes      29          Yes
# 1   1    Male             0     Yes        Yes      58          Yes
# 2   2    Male             0     Yes         No      58          Yes
# 3   3  Female             0      No         No       1          Yes
# 4   4  Female             0      No         No       1          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... TechSupport StreamingTV  \
# 0            No             DSL            Yes  ...         Yes          No
# 1            No             DSL            Yes  ...         Yes         Yes
# 2           Yes     Fiber optic             No  ...          No         Yes
# 3            No     Fiber optic             No  ...          No          No
# 4            No     Fiber optic             No  ...          No          No
#
#   StreamingMovies        Contract PaperlessBilling            PaymentMethod  \
# 0              No        One year              Yes             Mailed check
# 1              No        Two year               No  Credit card (automatic)
# 2             Yes  Month-to-month              Yes         Electronic check
# 3              No  Month-to-month              Yes         Electronic check
# 4              No  Month-to-month              Yes         Electronic check
#
#   MonthlyCharges TotalCharges  Churn  Total_vs_monthly
# 0          60.10      1653.85      0         27.518303
# 1          69.50      3778.20      0         54.362590
# 2         100.40      5841.35      0         58.180777
# 3          69.70        70.70      1          1.014347
# 4          70.45        70.45      1          1.000000
#
# [5 rows x 22 columns]

# %%
df.to_pickle('df_att.pkl')
