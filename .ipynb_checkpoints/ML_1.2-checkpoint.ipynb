# %%
from catboost import CatBoostClassifier
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.metrics import ConfusionMatrixDisplay, recall_score, roc_auc_score
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from IPython.display import display

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import joblib

# %% [markdown]
# #### Nesse notebook, geraremos um modelo simplificado, sem GridSearch, sem StratifiedKFold, apenas pra gerar nossa primeira pravisão e submissão, e avaliar o progresso do nosso modelo ao longo do percurso.

# %%
class FeatureEngineer(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        X=X.copy()
        X['log_MonthlyCharges'] = np.log1p(df['MonthlyCharges'])
        return X

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594194 entries, 0 to 594193
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                594194 non-null  int64
#  1   gender            594194 non-null  category
#  2   SeniorCitizen     594194 non-null  category
#  3   Partner           594194 non-null  category
#  4   Dependents        594194 non-null  category
#  5   tenure            594194 non-null  int64
#  6   PhoneService      594194 non-null  category
#  7   MultipleLines     594194 non-null  category
#  8   InternetService   594194 non-null  category
#  9   OnlineSecurity    594194 non-null  category
#  10  OnlineBackup      594194 non-null  category
#  11  DeviceProtection  594194 non-null  category
#  12  TechSupport       594194 non-null  category
#  13  StreamingTV       594194 non-null  category
#  14  StreamingMovies   594194 non-null  category
#  15  Contract          594194 non-null  category
#  16  PaperlessBilling  594194 non-null  category
#  17  PaymentMethod     594194 non-null  category
#  18  MonthlyCharges    594194 non-null  float64
#  19  TotalCharges      594194 non-null  float64
#  20  Churn             594194 non-null  int64
# dtypes: category(16), float64(2), int64(3)
# memory usage: 31.7 MB

# %%
df = joblib.load('df_att.pkl')

index = df['id']

target = 'Churn'

X = df.drop([target, 'id'], axis=1)
y = df[target]

# %%
X.head()
# Out:
#    gender SeniorCitizen  ... MonthlyCharges TotalCharges
# 0    Male             0  ...          60.10      1653.85
# 1    Male             0  ...          69.50      3778.20
# 2    Male             0  ...         100.40      5841.35
# 3  Female             0  ...          69.70        70.70
# 4  Female             0  ...          70.45        70.45
#
# [5 rows x 19 columns]

# %%
def extract_xy(df):
    target = 'Churn'
    X = df.drop([target, 'id'], axis=1)
    y = df[target]
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2)

    return X_train, X_val, y_train, y_val

# %%
X_train, X_val, y_train, y_val = extract_xy(df)

cat_features = X_train.select_dtypes(exclude='number').columns.tolist()
num_features = X_train.select_dtypes(include='number').columns.tolist()

# %%
X_train
# Out:
#         gender SeniorCitizen  ... TotalCharges log_MonthlyCharges
# 582467    Male             0  ...      5514.95           4.620059
# 287479    Male             0  ...        54.55           4.017284
# 140287  Female             0  ...      7782.85           4.759178
# 265225    Male             0  ...       337.90           3.034953
# 146500    Male             0  ...      6603.00           4.702297
#
# [5 rows x 20 columns]

# %%
model = CatBoostClassifier(iterations = 108, learning_rate=0.6, depth=6, l2_leaf_reg=1.2, border_count=150, eval_metric='AUC', cat_features=cat_features, verbose=100)

# %%
pipe = Pipeline([
    ('fe', FeatureEngineer()),
    ('model', model)
])

# %%
pipe.fit(X_train, y_train)
# Out:
# 0:	total: 389ms	remaining: 1m 17s
# 100:	total: 34.9s	remaining: 34.2s
# 199:	total: 1m 10s	remaining: 0us
# Pipeline(steps=[('fe', FeatureEngineer()),
#                 ('model',
#                  CatBoostClassifier(border_count=150, cat_features=['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod'], depth=6, eval_metric='AUC', iterations=200, l2_leaf_reg=1.2, learning_rate=0.6, verbose=100))])

# %%
pred = pipe.predict(X_val)

score = roc_auc_score(y_val, pred)
score
# Out:
# 0.7844358544915848

# %%
pipe.named_steps['model'].feature_importances_
# Out:
# array([ 0.17713706,  1.39229662,  0.18504298,  0.86399375, 31.25952549,
#         1.36094657,  1.11251066,  0.82536033,  2.43169525,  0.58196705,
#         0.75044367,  1.81315086,  0.45420129,  0.40028036, 16.87009674,
#         7.40644057,  6.55758661,  5.02114993,  6.03929633, 14.49687788])

# %%
X_train_fe.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'log_MonthlyCharges'],
#       dtype='object')

# %%
pipe.fit(X, y)
# Out:
# 0:	total: 398ms	remaining: 42.6s
# 100:	total: 22.9s	remaining: 1.59s
# 107:	total: 24.5s	remaining: 0us
# Pipeline(steps=[('fe', FeatureEngineer()),
#                 ('model',
#                  CatBoostClassifier(border_count=150, cat_features=['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod'], depth=6, eval_metric='AUC', iterations=108, l2_leaf_reg=1.2, learning_rate=0.6, verbose=100))])

# %%
test = joblib.load('test_att.pkl')
index = test['id']
test = test.drop('id', axis=1)

# %%
test_fe = pipe.named_steps['fe'].transform(test)

# %%
test_predict = model.predict_proba(test_fe)[:,1]
test_predict
# Out:
# array([5.59109903e-03, 3.81655108e-04, 1.56425682e-01, ...,
#        8.62071629e-02, 2.18263664e-02, 4.07002178e-01], shape=(254655,))

# %%
df_test = pd.DataFrame({'id': index, 'Churn': test_predict})

df_test.head(3)
# Out:
#        id     Churn
# 0  594194  0.005591
# 1  594195  0.000382
# 2  594196  0.156426

# %%
df_test.to_csv('1.1_submission.csv', index=False)

# %%
predict = model.predict(X_val)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 predict = model.predict(X_val)
#
# NameError: name 'model' is not defined

# %%
ConfusionMatrixDisplay.from_predictions(y_val, predict, normalize='true')

# %%
recall = recall_score(y_val, predict)

# %%
recall
# Out:
# 0.6426426426426426
